# %%
from selenium import webdriver
browser = webdriver.Edge(r"C:\Users\th056\Documents\Google-Image-Scraper\webdriver\msedgedriver.exe")
browser.get("https://www.google.com")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 from selenium import webdriver
# ----> 2 browser = webdriver.Edge(r"C:\Users\th056\Documents\Google-Image-Scraper\webdriver\msedgedriver.exe")
#       3 browser.get("https://www.google.com")
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\edge\webdriver.py:61, in WebDriver.__init__(self, executable_path, capabilities, port, verbose, service_log_path, log_path, keep_alive)
#      58 if capabilities is None:
#      59     capabilities = DesiredCapabilities.EDGE
# ---> 61 RemoteWebDriver.__init__(
#      62     self,
#      63     command_executor=RemoteConnection('http://localhost:%d' % self.port,
#      64                                       resolve_ip=False,
#      65                                       keep_alive=keep_alive),
#      66     desired_capabilities=capabilities)
#      67 self._is_remote = False
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:157, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     154 if browser_profile is not None:
#     155     warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                   DeprecationWarning, stacklevel=2)
# --> 157 self.start_session(capabilities, browser_profile)
#     158 self._switch_to = SwitchTo(self)
#     159 self._mobile = Mobile(self)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:252, in WebDriver.start_session(self, capabilities, browser_profile)
#     249 w3c_caps = _make_w3c_caps(capabilities)
#     250 parameters = {"capabilities": w3c_caps,
#     251               "desiredCapabilities": capabilities}
# --> 252 response = self.execute(Command.NEW_SESSION, parameters)
#     253 if 'sessionId' not in response:
#     254     response = response['value']
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:319, in WebDriver.execute(self, driver_command, params)
#     316         params['sessionId'] = self.session_id
#     318 params = self._wrap_value(params)
# --> 319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
#     321     self.error_handler.check_response(response)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:374, in RemoteConnection.execute(self, command, params)
#     372 data = utils.dump_json(params)
#     373 url = '%s%s' % (self._url, path)
# --> 374 return self._request(command_info[0], url, body=data)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:402, in RemoteConnection._request(self, method, url, body)
#     400 else:
#     401     http = urllib3.PoolManager(timeout=self._timeout)
# --> 402     resp = http.request(method, url, body=body, headers=headers)
#     404     statuscode = resp.status
#     405     if not hasattr(resp, 'getheader'):
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\poolmanager.py:433, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     423 if u.scheme is None:
#     424     warnings.warn(
#     425         "URLs without a scheme (ie 'https://') are deprecated and will raise an error "
#     426         "in a future version of urllib3. To avoid this DeprecationWarning ensure all URLs "
#    (...)
#     430         stacklevel=2,
#     431     )
# --> 433 conn = self.connection_from_host(u.host, port=u.port, scheme=u.scheme)
#     435 kw["assert_same_host"] = False
#     436 kw["redirect"] = False
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\poolmanager.py:304, in PoolManager.connection_from_host(self, host, port, scheme, pool_kwargs)
#     301 request_context["port"] = port
#     302 request_context["host"] = host
# --> 304 return self.connection_from_context(request_context)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\poolmanager.py:329, in PoolManager.connection_from_context(self, request_context)
#     326     raise URLSchemeUnknown(scheme)
#     327 pool_key = pool_key_constructor(request_context)
# --> 329 return self.connection_from_pool_key(pool_key, request_context=request_context)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\poolmanager.py:352, in PoolManager.connection_from_pool_key(self, pool_key, request_context)
#     350     host = request_context["host"]
#     351     port = request_context["port"]
# --> 352     pool = self._new_pool(scheme, host, port, request_context=request_context)
#     353     self.pools[pool_key] = pool
#     355 return pool
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\poolmanager.py:266, in PoolManager._new_pool(self, scheme, host, port, request_context)
#     263     for kw in SSL_KEYWORDS:
#     264         request_context.pop(kw, None)
# --> 266 return pool_cls(host, port, **request_context)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\connectionpool.py:196, in HTTPConnectionPool.__init__(self, host, port, timeout, maxsize, block, headers, retries, _proxy, _proxy_headers, _proxy_config, **conn_kw)
#     193 RequestMethods.__init__(self, headers)
#     195 if not isinstance(timeout, Timeout):
# --> 196     timeout = Timeout.from_float(timeout)
#     198 if retries is None:
#     199     retries = Retry.DEFAULT
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\util\timeout.py:186, in Timeout.from_float(cls, timeout)
#     172 @classmethod
#     173 def from_float(cls, timeout: _TYPE_TIMEOUT) -> Timeout:
#     174     """Create a new Timeout from a legacy timeout value.
#     175
#     176     The timeout value used by httplib.py sets the same timeout on the
#    (...)
#     184     :rtype: :class:`Timeout`
#     185     """
# --> 186     return Timeout(read=timeout, connect=timeout)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\util\timeout.py:115, in Timeout.__init__(self, total, connect, read)
#     109 def __init__(
#     110     self,
#     111     total: _TYPE_TIMEOUT = None,
#     112     connect: _TYPE_TIMEOUT = _DEFAULT_TIMEOUT,
#     113     read: _TYPE_TIMEOUT = _DEFAULT_TIMEOUT,
#     114 ) -> None:
# --> 115     self._connect = self._validate_timeout(connect, "connect")
#     116     self._read = self._validate_timeout(read, "read")
#     117     self.total = self._validate_timeout(total, "total")
#
# File c:\ProgramData\miniconda3\Lib\site-packages\urllib3\util\timeout.py:152, in Timeout._validate_timeout(cls, value, name)
#     150     float(value)
#     151 except (TypeError, ValueError):
# --> 152     raise ValueError(
#     153         "Timeout value %s was %s, but it must be an "
#     154         "int, float or None." % (name, value)
#     155     ) from None
#     157 try:
#     158     if value <= 0:
#
# ValueError: Timeout value connect was <object object at 0x0000020E4BEB48E0>, but it must be an int, float or None.
